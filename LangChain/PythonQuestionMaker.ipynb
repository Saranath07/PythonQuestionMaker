# %%
# # All pip installs
# !pip install langchain
# !pip install -qU langchain-groq
# !pip install langchain_community
# Out:
# Collecting langchain
#   Downloading https://files.pythonhosted.org/packages/5d/a7/23dd2a34aded62c6fe31918f306517a36b182e02780c8ea93e2af5ab4cd5/langchain-0.2.8-py3-none-any.whl (987kB)
#      |████████████████████████████████| 993kB 1.3MB/s eta 0:00:01
# Collecting pydantic<3,>=1 (from langchain)
#   Downloading https://files.pythonhosted.org/packages/1f/fa/b7f815b8c9ad021c07f88875b601222ef5e70619391ade4a49234d12d278/pydantic-2.8.2-py3-none-any.whl (423kB)
#      |████████████████████████████████| 430kB 16.5MB/s eta 0:00:01
# Collecting langchain-text-splitters<0.3.0,>=0.2.0 (from langchain)
#   Using cached https://files.pythonhosted.org/packages/06/76/9e0ca1b8881f64bf927f2205bf6c43a085c04646a71d911b3c05d76e90bb/langchain_text_splitters-0.2.2-py3-none-any.whl
# Collecting PyYAML>=5.3 (from langchain)
#   Downloading https://files.pythonhosted.org/packages/7f/5d/2779ea035ba1e533c32ed4a249b4e0448f583ba10830b21a3cddafe11a4e/PyYAML-6.0.1-cp38-cp38-macosx_10_9_x86_64.whl (191kB)
#      |████████████████████████████████| 194kB 10.8MB/s eta 0:00:01
# Collecting langsmith<0.2.0,>=0.1.17 (from langchain)
#   Downloading https://files.pythonhosted.org/packages/12/87/ea668d9441ad831a80223d5a5c6c787d18b6094b00c67a179327ed47c838/langsmith-0.1.86-py3-none-any.whl (129kB)
#      |████████████████████████████████| 133kB 15.1MB/s eta 0:00:01
# Collecting tenacity!=8.4.0,<9.0.0,>=8.1.0 (from langchain)
#   Downloading https://files.pythonhosted.org/packages/d2/3f/8ba87d9e287b9d385a02a7114ddcef61b26f86411e121c9003eb509a1773/tenacity-8.5.0-py3-none-any.whl
# Collecting SQLAlchemy<3,>=1.4 (from langchain)
#   Downloading https://files.pythonhosted.org/packages/14/4e/7978ac79bcf9080b46375128b9f710df20ad6ce44d133a175fda27eb2854/SQLAlchemy-2.0.31-cp38-cp38-macosx_10_9_x86_64.whl (2.1MB)
#      |████████████████████████████████| 2.1MB 17.5MB/s eta 0:00:01
# Collecting numpy<2,>=1; python_version < "3.12" (from langchain)
#   Downloading https://files.pythonhosted.org/packages/11/10/943cfb579f1a02909ff96464c69893b1d25be3731b5d3652c2e0cf1281ea/numpy-1.24.4-cp38-cp38-macosx_10_9_x86_64.whl (19.8MB)
#      |████████████████████████████████| 19.8MB 16.6MB/s eta 0:00:01   |█████▉                          | 3.6MB 8.4MB/s eta 0:00:02     |█████████▍                      | 5.8MB 8.4MB/s eta 0:00:02     |███████████▌                    | 7.1MB 8.4MB/s eta 0:00:02     |█████████████▍                  | 8.3MB 8.4MB/s eta 0:00:02     |████████████████▋               | 10.3MB 8.4MB/s eta 0:00:02     |████████████████████████████    | 17.3MB 16.6MB/s eta 0:00:01
# Collecting requests<3,>=2 (from langchain)
#   Downloading https://files.pythonhosted.org/packages/f9/9b/335f9764261e915ed497fcdeb11df5dfd6f7bf257d4a6a2a686d80da4d54/requests-2.32.3-py3-none-any.whl (64kB)
#      |████████████████████████████████| 71kB 12.1MB/s eta 0:00:01
# Collecting aiohttp<4.0.0,>=3.8.3 (from langchain)
#   Downloading https://files.pythonhosted.org/packages/ed/aa/555091d9ad3e036a91922bfbf6d4fc9906e78b22d776c25150caa96cb387/aiohttp-3.9.5-cp38-cp38-macosx_10_9_x86_64.whl (402kB)
#      |████████████████████████████████| 409kB 18.1MB/s eta 0:00:01
# Collecting async-timeout<5.0.0,>=4.0.0; python_version < "3.11" (from langchain)
#   Downloading https://files.pythonhosted.org/packages/a7/fa/e01228c2938de91d47b307831c62ab9e4001e747789d0b05baf779a6488c/async_timeout-4.0.3-py3-none-any.whl
# Collecting langchain-core<0.3.0,>=0.2.19 (from langchain)
#   Downloading https://files.pythonhosted.org/packages/a9/dd/e259bcdccd5f37a7302f2da774ce1bba818927caeb781993b7b17ed9a186/langchain_core-0.2.19-py3-none-any.whl (366kB)
#      |████████████████████████████████| 368kB 9.7MB/s eta 0:00:01
# Collecting typing-extensions>=4.6.1; python_version < "3.13" (from pydantic<3,>=1->langchain)
#   Downloading https://files.pythonhosted.org/packages/26/9f/ad63fc0248c5379346306f8668cda6e2e2e9c95e01216d2b8ffd9ff037d0/typing_extensions-4.12.2-py3-none-any.whl
# Collecting annotated-types>=0.4.0 (from pydantic<3,>=1->langchain)
#   Downloading https://files.pythonhosted.org/packages/78/b6/6307fbef88d9b5ee7421e68d78a9f162e0da4900bc5f5793f6d3d0e34fb8/annotated_types-0.7.0-py3-none-any.whl
# Collecting pydantic-core==2.20.1 (from pydantic<3,>=1->langchain)
#   Downloading https://files.pythonhosted.org/packages/ba/45/809b121a22a7bf578325be5a35ea98e2fb69c7d497859a4e28659df8f685/pydantic_core-2.20.1-cp38-cp38-macosx_10_12_x86_64.whl (1.8MB)
#      |████████████████████████████████| 1.8MB 5.8MB/s eta 0:00:01
# Collecting orjson<4.0.0,>=3.9.14 (from langsmith<0.2.0,>=0.1.17->langchain)
#   Downloading https://files.pythonhosted.org/packages/5c/6f/ca9ec2a393b05a6b69a0ebd378d4159f2db764d2a3dbe2ffa458e363f42c/orjson-3.10.6-cp38-cp38-macosx_10_15_x86_64.macosx_11_0_arm64.macosx_10_15_universal2.whl (249kB)
#      |████████████████████████████████| 256kB 11.5MB/s eta 0:00:01
# Collecting greenlet!=0.4.17; python_version < "3.13" and (platform_machine == "aarch64" or (platform_machine == "ppc64le" or (platform_machine == "x86_64" or (platform_machine == "amd64" or (platform_machine == "AMD64" or (platform_machine == "win32" or platform_machine == "WIN32")))))) (from SQLAlchemy<3,>=1.4->langchain)
#   Using cached https://files.pythonhosted.org/packages/17/14/3bddb1298b9a6786539ac609ba4b7c9c0842e12aa73aaa4d8d73ec8f8185/greenlet-3.0.3.tar.gz
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# Collecting urllib3<3,>=1.21.1 (from requests<3,>=2->langchain)
#   Downloading https://files.pythonhosted.org/packages/ca/1c/89ffc63a9605b583d5df2be791a27bc1a42b7c32bab68d3c8f2f73a98cd4/urllib3-2.2.2-py3-none-any.whl (121kB)
#      |████████████████████████████████| 122kB 12.6MB/s eta 0:00:01
# Collecting certifi>=2017.4.17 (from requests<3,>=2->langchain)
#   Downloading https://files.pythonhosted.org/packages/1c/d5/c84e1a17bf61d4df64ca866a1c9a913874b4e9bdc131ec689a0ad013fb36/certifi-2024.7.4-py3-none-any.whl (162kB)
#      |████████████████████████████████| 163kB 990kB/s eta 0:00:01
# Collecting idna<4,>=2.5 (from requests<3,>=2->langchain)
#   Downloading https://files.pythonhosted.org/packages/e5/3e/741d8c82801c347547f8a2a06aa57dbb1992be9e948df2ea0eda2c8b79e8/idna-3.7-py3-none-any.whl (66kB)
#      |████████████████████████████████| 71kB 10.2MB/s eta 0:00:01
# Collecting charset-normalizer<4,>=2 (from requests<3,>=2->langchain)
#   Downloading https://files.pythonhosted.org/packages/13/82/83c188028b6f38d39538442dd127dc794c602ae6d45d66c469f4063a4c30/charset_normalizer-3.3.2-cp38-cp38-macosx_10_9_x86_64.whl (121kB)
#      |████████████████████████████████| 122kB 8.4MB/s eta 0:00:01
# Collecting multidict<7.0,>=4.5 (from aiohttp<4.0.0,>=3.8.3->langchain)
#   Downloading https://files.pythonhosted.org/packages/6c/13/97f4a2e0e26b7c6e2469de03f1efc255ce2f984a537c301d957762a23eba/multidict-6.0.5-cp38-cp38-macosx_10_9_x86_64.whl
# Collecting yarl<2.0,>=1.0 (from aiohttp<4.0.0,>=3.8.3->langchain)
#   Downloading https://files.pythonhosted.org/packages/46/ea/8404aa172ffe74da750efeb09aa293bf0247fa6ab4f593aea93f85f74844/yarl-1.9.4-cp38-cp38-macosx_10_9_x86_64.whl (83kB)
#      |████████████████████████████████| 92kB 14.8MB/s eta 0:00:01
# Collecting aiosignal>=1.1.2 (from aiohttp<4.0.0,>=3.8.3->langchain)
#   Downloading https://files.pythonhosted.org/packages/76/ac/a7305707cb852b7e16ff80eaf5692309bde30e2b1100a1fcacdc8f731d97/aiosignal-1.3.1-py3-none-any.whl
# Collecting frozenlist>=1.1.1 (from aiohttp<4.0.0,>=3.8.3->langchain)
#   Downloading https://files.pythonhosted.org/packages/07/eb/71b5531dfb71eb6272b6e2281139d7d46b6adaf43c59850bc8ff64ac1860/frozenlist-1.4.1-cp38-cp38-macosx_10_9_x86_64.whl (55kB)
#      |████████████████████████████████| 61kB 11.4MB/s eta 0:00:01
# Collecting attrs>=17.3.0 (from aiohttp<4.0.0,>=3.8.3->langchain)
#   Downloading https://files.pythonhosted.org/packages/e0/44/827b2a91a5816512fcaf3cc4ebc465ccd5d598c45cefa6703fcf4a79018f/attrs-23.2.0-py3-none-any.whl (60kB)
#      |████████████████████████████████| 61kB 13.2MB/s eta 0:00:01
# Collecting packaging<25,>=23.2 (from langchain-core<0.3.0,>=0.2.19->langchain)
#   Using cached https://files.pythonhosted.org/packages/08/aa/cc0199a5f0ad350994d660967a8efb233fe0416e4639146c089643407ce6/packaging-24.1-py3-none-any.whl
# Collecting jsonpatch<2.0,>=1.33 (from langchain-core<0.3.0,>=0.2.19->langchain)
#   Using cached https://files.pythonhosted.org/packages/73/07/02e16ed01e04a374e644b575638ec7987ae846d25ad97bcc9945a3ee4b0e/jsonpatch-1.33-py2.py3-none-any.whl
# Collecting jsonpointer>=1.9 (from jsonpatch<2.0,>=1.33->langchain-core<0.3.0,>=0.2.19->langchain)
#   Downloading https://files.pythonhosted.org/packages/71/92/5e77f98553e9e75130c78900d000368476aed74276eb8ae8796f65f00918/jsonpointer-3.0.0-py2.py3-none-any.whl
# Building wheels for collected packages: greenlet
#   Building wheel for greenlet (PEP 517) ... error
#   ERROR: Command errored out with exit status 1:
#    command: /Users/saranath/PythonQuestionMaker/myvenv/bin/python3 /Users/saranath/PythonQuestionMaker/myvenv/lib/python3.8/site-packages/pip/_vendor/pep517/_in_process.py build_wheel /var/folders/1n/pwgq7wc56_9b_0rsfsb8v_180000gn/T/tmp5gtg66lt
#        cwd: /private/var/folders/1n/pwgq7wc56_9b_0rsfsb8v_180000gn/T/pip-install-i4z5opg0/greenlet
#   Complete output (213 lines):
#   running bdist_wheel
#   running build
#   running build_py
#   creating build
#   creating build/lib.macosx-10.14.6-x86_64-cpython-38
#   creating build/lib.macosx-10.14.6-x86_64-cpython-38/greenlet
#   copying src/greenlet/__init__.py -> build/lib.macosx-10.14.6-x86_64-cpython-38/greenlet
#   creating build/lib.macosx-10.14.6-x86_64-cpython-38/greenlet/platform
#   copying src/greenlet/platform/__init__.py -> build/lib.macosx-10.14.6-x86_64-cpython-38/greenlet/platform
#   creating build/lib.macosx-10.14.6-x86_64-cpython-38/greenlet/tests
#   copying src/greenlet/tests/test_version.py -> build/lib.macosx-10.14.6-x86_64-cpython-38/greenlet/tests
#   copying src/greenlet/tests/test_weakref.py -> build/lib.macosx-10.14.6-x86_64-cpython-38/greenlet/tests
#   copying src/greenlet/tests/fail_slp_switch.py -> build/lib.macosx-10.14.6-x86_64-cpython-38/greenlet/tests
#   copying src/greenlet/tests/test_gc.py -> build/lib.macosx-10.14.6-x86_64-cpython-38/greenlet/tests
#   copying src/greenlet/tests/leakcheck.py -> build/lib.macosx-10.14.6-x86_64-cpython-38/greenlet/tests
#   copying src/greenlet/tests/fail_switch_two_greenlets.py -> build/lib.macosx-10.14.6-x86_64-cpython-38/greenlet/tests
#   copying src/greenlet/tests/test_generator.py -> build/lib.macosx-10.14.6-x86_64-cpython-38/greenlet/tests
#   copying src/greenlet/tests/test_greenlet_trash.py -> build/lib.macosx-10.14.6-x86_64-cpython-38/greenlet/tests
#   copying src/greenlet/tests/test_throw.py -> build/lib.macosx-10.14.6-x86_64-cpython-38/greenlet/tests
#   copying src/greenlet/tests/test_tracing.py -> build/lib.macosx-10.14.6-x86_64-cpython-38/greenlet/tests
#   copying src/greenlet/tests/fail_cpp_exception.py -> build/lib.macosx-10.14.6-x86_64-cpython-38/greenlet/tests
#   copying src/greenlet/tests/fail_switch_three_greenlets.py -> build/lib.macosx-10.14.6-x86_64-cpython-38/greenlet/tests
#   copying src/greenlet/tests/test_cpp.py -> build/lib.macosx-10.14.6-x86_64-cpython-38/greenlet/tests
#   copying src/greenlet/tests/test_contextvars.py -> build/lib.macosx-10.14.6-x86_64-cpython-38/greenlet/tests
#   copying src/greenlet/tests/test_greenlet.py -> build/lib.macosx-10.14.6-x86_64-cpython-38/greenlet/tests
#   copying src/greenlet/tests/test_extension_interface.py -> build/lib.macosx-10.14.6-x86_64-cpython-38/greenlet/tests
#   copying src/greenlet/tests/fail_clearing_run_switches.py -> build/lib.macosx-10.14.6-x86_64-cpython-38/greenlet/tests
#   copying src/greenlet/tests/__init__.py -> build/lib.macosx-10.14.6-x86_64-cpython-38/greenlet/tests
#   copying src/greenlet/tests/fail_switch_three_greenlets2.py -> build/lib.macosx-10.14.6-x86_64-cpython-38/greenlet/tests
#   copying src/greenlet/tests/fail_initialstub_already_started.py -> build/lib.macosx-10.14.6-x86_64-cpython-38/greenlet/tests
#   copying src/greenlet/tests/test_generator_nested.py -> build/lib.macosx-10.14.6-x86_64-cpython-38/greenlet/tests
#   copying src/greenlet/tests/test_stack_saved.py -> build/lib.macosx-10.14.6-x86_64-cpython-38/greenlet/tests
#   copying src/greenlet/tests/test_leaks.py -> build/lib.macosx-10.14.6-x86_64-cpython-38/greenlet/tests
#   running egg_info
#   writing src/greenlet.egg-info/PKG-INFO
#   writing dependency_links to src/greenlet.egg-info/dependency_links.txt
#   writing requirements to src/greenlet.egg-info/requires.txt
#   writing top-level names to src/greenlet.egg-info/top_level.txt
#   reading manifest file 'src/greenlet.egg-info/SOURCES.txt'
#   reading manifest template 'MANIFEST.in'
#   warning: no previously-included files found matching 'benchmarks/*.json'
#   no previously-included directories found matching 'docs/_build'
#   warning: no files found matching '*.py' under directory 'appveyor'
#   warning: no previously-included files matching '*.pyc' found anywhere in distribution
#   warning: no previously-included files matching '*.pyd' found anywhere in distribution
#   warning: no previously-included files matching '*.so' found anywhere in distribution
#   warning: no previously-included files matching '.coverage' found anywhere in distribution
#   adding license file 'LICENSE'
#   adding license file 'LICENSE.PSF'
#   adding license file 'AUTHORS'
#   writing manifest file 'src/greenlet.egg-info/SOURCES.txt'
#   copying src/greenlet/TBrokenGreenlet.cpp -> build/lib.macosx-10.14.6-x86_64-cpython-38/greenlet
#   copying src/greenlet/TExceptionState.cpp -> build/lib.macosx-10.14.6-x86_64-cpython-38/greenlet
#   copying src/greenlet/TGreenlet.cpp -> build/lib.macosx-10.14.6-x86_64-cpython-38/greenlet
#   copying src/greenlet/TGreenletGlobals.cpp -> build/lib.macosx-10.14.6-x86_64-cpython-38/greenlet
#   copying src/greenlet/TMainGreenlet.cpp -> build/lib.macosx-10.14.6-x86_64-cpython-38/greenlet
#   copying src/greenlet/TPythonState.cpp -> build/lib.macosx-10.14.6-x86_64-cpython-38/greenlet
#   copying src/greenlet/TStackState.cpp -> build/lib.macosx-10.14.6-x86_64-cpython-38/greenlet
#   copying src/greenlet/TThreadStateDestroy.cpp -> build/lib.macosx-10.14.6-x86_64-cpython-38/greenlet
#   copying src/greenlet/TUserGreenlet.cpp -> build/lib.macosx-10.14.6-x86_64-cpython-38/greenlet
#   copying src/greenlet/greenlet.cpp -> build/lib.macosx-10.14.6-x86_64-cpython-38/greenlet
#   copying src/greenlet/greenlet.h -> build/lib.macosx-10.14.6-x86_64-cpython-38/greenlet
#   copying src/greenlet/greenlet_allocator.hpp -> build/lib.macosx-10.14.6-x86_64-cpython-38/greenlet
#   copying src/greenlet/greenlet_compiler_compat.hpp -> build/lib.macosx-10.14.6-x86_64-cpython-38/greenlet
#   copying src/greenlet/greenlet_cpython_add_pending.hpp -> build/lib.macosx-10.14.6-x86_64-cpython-38/greenlet
#   copying src/greenlet/greenlet_cpython_compat.hpp -> build/lib.macosx-10.14.6-x86_64-cpython-38/greenlet
#   copying src/greenlet/greenlet_exceptions.hpp -> build/lib.macosx-10.14.6-x86_64-cpython-38/greenlet
#   copying src/greenlet/greenlet_greenlet.hpp -> build/lib.macosx-10.14.6-x86_64-cpython-38/greenlet
#   copying src/greenlet/greenlet_internal.hpp -> build/lib.macosx-10.14.6-x86_64-cpython-38/greenlet
#   copying src/greenlet/greenlet_refs.hpp -> build/lib.macosx-10.14.6-x86_64-cpython-38/greenlet
#   copying src/greenlet/greenlet_slp_switch.hpp -> build/lib.macosx-10.14.6-x86_64-cpython-38/greenlet
#   copying src/greenlet/greenlet_thread_state.hpp -> build/lib.macosx-10.14.6-x86_64-cpython-38/greenlet
#   copying src/greenlet/greenlet_thread_state_dict_cleanup.hpp -> build/lib.macosx-10.14.6-x86_64-cpython-38/greenlet
#   copying src/greenlet/greenlet_thread_support.hpp -> build/lib.macosx-10.14.6-x86_64-cpython-38/greenlet
#   copying src/greenlet/slp_platformselect.h -> build/lib.macosx-10.14.6-x86_64-cpython-38/greenlet
#   copying src/greenlet/platform/setup_switch_x64_masm.cmd -> build/lib.macosx-10.14.6-x86_64-cpython-38/greenlet/platform
#   copying src/greenlet/platform/switch_aarch64_gcc.h -> build/lib.macosx-10.14.6-x86_64-cpython-38/greenlet/platform
#   copying src/greenlet/platform/switch_alpha_unix.h -> build/lib.macosx-10.14.6-x86_64-cpython-38/greenlet/platform
#   copying src/greenlet/platform/switch_amd64_unix.h -> build/lib.macosx-10.14.6-x86_64-cpython-38/greenlet/platform
#   copying src/greenlet/platform/switch_arm32_gcc.h -> build/lib.macosx-10.14.6-x86_64-cpython-38/greenlet/platform
#   copying src/greenlet/platform/switch_arm32_ios.h -> build/lib.macosx-10.14.6-x86_64-cpython-38/greenlet/platform
#   copying src/greenlet/platform/switch_arm64_masm.asm -> build/lib.macosx-10.14.6-x86_64-cpython-38/greenlet/platform
#   copying src/greenlet/platform/switch_arm64_masm.obj -> build/lib.macosx-10.14.6-x86_64-cpython-38/greenlet/platform
#   copying src/greenlet/platform/switch_arm64_msvc.h -> build/lib.macosx-10.14.6-x86_64-cpython-38/greenlet/platform
#   copying src/greenlet/platform/switch_csky_gcc.h -> build/lib.macosx-10.14.6-x86_64-cpython-38/greenlet/platform
#   copying src/greenlet/platform/switch_loongarch64_linux.h -> build/lib.macosx-10.14.6-x86_64-cpython-38/greenlet/platform
#   copying src/greenlet/platform/switch_m68k_gcc.h -> build/lib.macosx-10.14.6-x86_64-cpython-38/greenlet/platform
#   copying src/greenlet/platform/switch_mips_unix.h -> build/lib.macosx-10.14.6-x86_64-cpython-38/greenlet/platform
#   copying src/greenlet/platform/switch_ppc64_aix.h -> build/lib.macosx-10.14.6-x86_64-cpython-38/greenlet/platform
#   copying src/greenlet/platform/switch_ppc64_linux.h -> build/lib.macosx-10.14.6-x86_64-cpython-38/greenlet/platform
#   copying src/greenlet/platform/switch_ppc_aix.h -> build/lib.macosx-10.14.6-x86_64-cpython-38/greenlet/platform
#   copying src/greenlet/platform/switch_ppc_linux.h -> build/lib.macosx-10.14.6-x86_64-cpython-38/greenlet/platform
#   copying src/greenlet/platform/switch_ppc_macosx.h -> build/lib.macosx-10.14.6-x86_64-cpython-38/greenlet/platform
#   copying src/greenlet/platform/switch_ppc_unix.h -> build/lib.macosx-10.14.6-x86_64-cpython-38/greenlet/platform
#   copying src/greenlet/platform/switch_riscv_unix.h -> build/lib.macosx-10.14.6-x86_64-cpython-38/greenlet/platform
#   copying src/greenlet/platform/switch_s390_unix.h -> build/lib.macosx-10.14.6-x86_64-cpython-38/greenlet/platform
#   copying src/greenlet/platform/switch_sparc_sun_gcc.h -> build/lib.macosx-10.14.6-x86_64-cpython-38/greenlet/platform
#   copying src/greenlet/platform/switch_x32_unix.h -> build/lib.macosx-10.14.6-x86_64-cpython-38/greenlet/platform
#   copying src/greenlet/platform/switch_x64_masm.asm -> build/lib.macosx-10.14.6-x86_64-cpython-38/greenlet/platform
#   copying src/greenlet/platform/switch_x64_masm.obj -> build/lib.macosx-10.14.6-x86_64-cpython-38/greenlet/platform
#   copying src/greenlet/platform/switch_x64_msvc.h -> build/lib.macosx-10.14.6-x86_64-cpython-38/greenlet/platform
#   copying src/greenlet/platform/switch_x86_msvc.h -> build/lib.macosx-10.14.6-x86_64-cpython-38/greenlet/platform
#   copying src/greenlet/platform/switch_x86_unix.h -> build/lib.macosx-10.14.6-x86_64-cpython-38/greenlet/platform
#   copying src/greenlet/tests/_test_extension.c -> build/lib.macosx-10.14.6-x86_64-cpython-38/greenlet/tests
#   copying src/greenlet/tests/_test_extension_cpp.cpp -> build/lib.macosx-10.14.6-x86_64-cpython-38/greenlet/tests
#   running build_ext
#   building 'greenlet._greenlet' extension
#   creating build/temp.macosx-10.14.6-x86_64-cpython-38
#   creating build/temp.macosx-10.14.6-x86_64-cpython-38/src
#   creating build/temp.macosx-10.14.6-x86_64-cpython-38/src/greenlet
#   clang -Wno-unused-result -Wsign-compare -Wunreachable-code -fno-common -dynamic -DNDEBUG -g -fwrapv -O3 -Wall -iwithsysroot/System/Library/Frameworks/System.framework/PrivateHeaders -iwithsysroot/Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.8/Headers -arch arm64 -arch x86_64 -I/Users/saranath/PythonQuestionMaker/myvenv/include -I/Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.8/include/python3.8 -c src/greenlet/greenlet.cpp -o build/temp.macosx-10.14.6-x86_64-cpython-38/src/greenlet/greenlet.o --std=gnu++11
#   In file included from src/greenlet/greenlet.cpp:9:
#   In file included from /Library/Developer/CommandLineTools/usr/bin/../include/c++/v1/cstdlib:85:
#   In file included from /Library/Developer/CommandLineTools/usr/bin/../include/c++/v1/stdlib.h:97:
#   In file included from /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdlib.h:62:
#   /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/sys/cdefs.h:807:2: error: Unsupported architecture
#   #error Unsupported architecture
#    ^
#   In file included from src/greenlet/greenlet.cpp:9:
#   In file included from /Library/Developer/CommandLineTools/usr/bin/../include/c++/v1/cstdlib:85:
#   In file included from /Library/Developer/CommandLineTools/usr/bin/../include/c++/v1/stdlib.h:97:
#   In file included from /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdlib.h:64:
#   In file included from /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/_types.h:27:
#   In file included from /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/sys/_types.h:33:
#   /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/machine/_types.h:34:2: error: architecture not supported
#   #error architecture not supported
#    ^
#   In file included from src/greenlet/greenlet.cpp:9:
#   In file included from /Library/Developer/CommandLineTools/usr/bin/../include/c++/v1/cstdlib:85:
#   In file included from /Library/Developer/CommandLineTools/usr/bin/../include/c++/v1/stdlib.h:97:
#   In file included from /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdlib.h:64:
#   In file included from /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/_types.h:27:
#   /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/sys/_types.h:55:9: error: unknown type name '__int64_t'
#   typedef __int64_t       __darwin_blkcnt_t;      /* total blocks */
#           ^
#   /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/sys/_types.h:56:9: error: unknown type name '__int32_t'; did you mean '__int128_t'?
#   typedef __int32_t       __darwin_blksize_t;     /* preferred block size */
#           ^
#   note: '__int128_t' declared here
#   /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/sys/_types.h:57:9: error: unknown type name '__int32_t'; did you mean '__int128_t'?
#   typedef __int32_t       __darwin_dev_t;         /* dev_t */
#           ^
#   note: '__int128_t' declared here
#   /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/sys/_types.h:60:9: error: unknown type name '__uint32_t'; did you mean '__uint128_t'?
#   typedef __uint32_t      __darwin_gid_t;         /* [???] process and group IDs */
#           ^
#   note: '__uint128_t' declared here
#   /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/sys/_types.h:61:9: error: unknown type name '__uint32_t'; did you mean '__uint128_t'?
#   typedef __uint32_t      __darwin_id_t;          /* [XSI] pid_t, uid_t, or gid_t*/
#           ^
#   note: '__uint128_t' declared here
#   /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/sys/_types.h:62:9: error: unknown type name '__uint64_t'
#   typedef __uint64_t      __darwin_ino64_t;       /* [???] Used for 64 bit inodes */
#           ^
#   /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/sys/_types.h:68:9: error: unknown type name '__darwin_natural_t'
#   typedef __darwin_natural_t __darwin_mach_port_name_t; /* Used by mach */
#           ^
#   /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/sys/_types.h:70:9: error: unknown type name '__uint16_t'; did you mean '__uint128_t'?
#   typedef __uint16_t      __darwin_mode_t;        /* [???] Some file attributes */
#           ^
#   note: '__uint128_t' declared here
#   /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/sys/_types.h:71:9: error: unknown type name '__int64_t'
#   typedef __int64_t       __darwin_off_t;         /* [???] Used for file sizes */
#           ^
#   /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/sys/_types.h:72:9: error: unknown type name '__int32_t'; did you mean '__int128_t'?
#   typedef __int32_t       __darwin_pid_t;         /* [???] process and group IDs */
#           ^
#   note: '__int128_t' declared here
#   /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/sys/_types.h:73:9: error: unknown type name '__uint32_t'; did you mean '__uint128_t'?
#   typedef __uint32_t      __darwin_sigset_t;      /* [???] signal set */
#           ^
#   note: '__uint128_t' declared here
#   /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/sys/_types.h:74:9: error: unknown type name '__int32_t'; did you mean '__int128_t'?
#   typedef __int32_t       __darwin_suseconds_t;   /* [???] microseconds */
#           ^
#   note: '__int128_t' declared here
#   /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/sys/_types.h:75:9: error: unknown type name '__uint32_t'; did you mean '__uint128_t'?
#   typedef __uint32_t      __darwin_uid_t;         /* [???] user IDs */
#           ^
#   note: '__uint128_t' declared here
#   /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/sys/_types.h:76:9: error: unknown type name '__uint32_t'; did you mean '__uint128_t'?
#   typedef __uint32_t      __darwin_useconds_t;    /* [???] microseconds */
#           ^
#   note: '__uint128_t' declared here
#   In file included from src/greenlet/greenlet.cpp:9:
#   In file included from /Library/Developer/CommandLineTools/usr/bin/../include/c++/v1/cstdlib:85:
#   In file included from /Library/Developer/CommandLineTools/usr/bin/../include/c++/v1/stdlib.h:97:
#   In file included from /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdlib.h:64:
#   /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/_types.h:43:9: error: unknown type name '__uint32_t'; did you mean '__uint128_t'?
#   typedef __uint32_t      __darwin_wctype_t;
#           ^
#   note: '__uint128_t' declared here
#   In file included from src/greenlet/greenlet.cpp:9:
#   In file included from /Library/Developer/CommandLineTools/usr/bin/../include/c++/v1/cstdlib:85:
#   In file included from /Library/Developer/CommandLineTools/usr/bin/../include/c++/v1/stdlib.h:97:
#   In file included from /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdlib.h:66:
#   In file included from /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/sys/wait.h:109:
#   In file included from /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/sys/signal.h:82:
#   /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/machine/signal.h:34:2: error: architecture not supported
#   #error architecture not supported
#    ^
#   In file included from src/greenlet/greenlet.cpp:9:
#   In file included from /Library/Developer/CommandLineTools/usr/bin/../include/c++/v1/cstdlib:85:
#   In file included from /Library/Developer/CommandLineTools/usr/bin/../include/c++/v1/stdlib.h:97:
#   In file included from /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdlib.h:66:
#   In file included from /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/sys/wait.h:109:
#   In file included from /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/sys/signal.h:146:
#   /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/machine/_mcontext.h:31:2: error: architecture not supported
#   #error architecture not supported
#    ^
#   fatal error: too many errors emitted, stopping now [-ferror-limit=]
#   20 errors generated.
#   error: command '/usr/bin/clang' failed with exit code 1
#   ----------------------------------------
#   ERROR: Failed building wheel for greenlet
#   Running setup.py clean for greenlet
# Failed to build greenlet
# ERROR: Could not build wheels for greenlet which use PEP 517 and cannot be installed directly
# WARNING: You are using pip version 19.2.3, however version 24.1.2 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.
# WARNING: You are using pip version 19.2.3, however version 24.1.2 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.
# Collecting langchain_community
#   Downloading https://files.pythonhosted.org/packages/3c/20/846d7fac8f6945a6f66b86cbef771f7697dfbb272d611a733cc9095329ce/langchain_community-0.2.7-py3-none-any.whl (2.2MB)
#      |████████████████████████████████| 2.2MB 1.7MB/s eta 0:00:01
# Collecting SQLAlchemy<3,>=1.4 (from langchain_community)
#   Using cached https://files.pythonhosted.org/packages/14/4e/7978ac79bcf9080b46375128b9f710df20ad6ce44d133a175fda27eb2854/SQLAlchemy-2.0.31-cp38-cp38-macosx_10_9_x86_64.whl
# Requirement already satisfied: langsmith<0.2.0,>=0.1.0 in ./myvenv/lib/python3.8/site-packages (from langchain_community) (0.1.86)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.1.0 in ./myvenv/lib/python3.8/site-packages (from langchain_community) (8.5.0)
# Collecting dataclasses-json<0.7,>=0.5.7 (from langchain_community)
#   Downloading https://files.pythonhosted.org/packages/c3/be/d0d44e092656fe7a06b55e6103cbce807cdbdee17884a5367c68c9860853/dataclasses_json-0.6.7-py3-none-any.whl
# Collecting langchain<0.3.0,>=0.2.7 (from langchain_community)
#   Using cached https://files.pythonhosted.org/packages/5d/a7/23dd2a34aded62c6fe31918f306517a36b182e02780c8ea93e2af5ab4cd5/langchain-0.2.8-py3-none-any.whl
# Requirement already satisfied: PyYAML>=5.3 in ./myvenv/lib/python3.8/site-packages (from langchain_community) (6.0.1)
# Requirement already satisfied: langchain-core<0.3.0,>=0.2.12 in ./myvenv/lib/python3.8/site-packages (from langchain_community) (0.2.19)
# Requirement already satisfied: requests<3,>=2 in ./myvenv/lib/python3.8/site-packages (from langchain_community) (2.32.3)
# Collecting numpy<2,>=1; python_version < "3.12" (from langchain_community)
#   Using cached https://files.pythonhosted.org/packages/11/10/943cfb579f1a02909ff96464c69893b1d25be3731b5d3652c2e0cf1281ea/numpy-1.24.4-cp38-cp38-macosx_10_9_x86_64.whl
# Collecting aiohttp<4.0.0,>=3.8.3 (from langchain_community)
#   Using cached https://files.pythonhosted.org/packages/ed/aa/555091d9ad3e036a91922bfbf6d4fc9906e78b22d776c25150caa96cb387/aiohttp-3.9.5-cp38-cp38-macosx_10_9_x86_64.whl
# Requirement already satisfied: typing-extensions>=4.6.0 in ./myvenv/lib/python3.8/site-packages (from SQLAlchemy<3,>=1.4->langchain_community) (4.12.2)
# Collecting greenlet!=0.4.17; python_version < "3.13" and (platform_machine == "aarch64" or (platform_machine == "ppc64le" or (platform_machine == "x86_64" or (platform_machine == "amd64" or (platform_machine == "AMD64" or (platform_machine == "win32" or platform_machine == "WIN32")))))) (from SQLAlchemy<3,>=1.4->langchain_community)
#   Using cached https://files.pythonhosted.org/packages/17/14/3bddb1298b9a6786539ac609ba4b7c9c0842e12aa73aaa4d8d73ec8f8185/greenlet-3.0.3.tar.gz
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in ./myvenv/lib/python3.8/site-packages (from langsmith<0.2.0,>=0.1.0->langchain_community) (3.10.6)
# Requirement already satisfied: pydantic<3,>=1; python_full_version < "3.12.4" in ./myvenv/lib/python3.8/site-packages (from langsmith<0.2.0,>=0.1.0->langchain_community) (2.8.2)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json<0.7,>=0.5.7->langchain_community)
#   Downloading https://files.pythonhosted.org/packages/96/d7/f318261e6ccbba86bdf626e07cd850981508fdaec52cfcdc4ac1030327ab/marshmallow-3.21.3-py3-none-any.whl (49kB)
#      |████████████████████████████████| 51kB 8.4MB/s eta 0:00:01
# Collecting typing-inspect<1,>=0.4.0 (from dataclasses-json<0.7,>=0.5.7->langchain_community)
#   Downloading https://files.pythonhosted.org/packages/65/f3/107a22063bf27bdccf2024833d3445f4eea42b2e598abfbd46f6a63b6cb0/typing_inspect-0.9.0-py3-none-any.whl
# Collecting async-timeout<5.0.0,>=4.0.0; python_version < "3.11" (from langchain<0.3.0,>=0.2.7->langchain_community)
#   Using cached https://files.pythonhosted.org/packages/a7/fa/e01228c2938de91d47b307831c62ab9e4001e747789d0b05baf779a6488c/async_timeout-4.0.3-py3-none-any.whl
# Collecting langchain-text-splitters<0.3.0,>=0.2.0 (from langchain<0.3.0,>=0.2.7->langchain_community)
#   Using cached https://files.pythonhosted.org/packages/06/76/9e0ca1b8881f64bf927f2205bf6c43a085c04646a71d911b3c05d76e90bb/langchain_text_splitters-0.2.2-py3-none-any.whl
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in ./myvenv/lib/python3.8/site-packages (from langchain-core<0.3.0,>=0.2.12->langchain_community) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in ./myvenv/lib/python3.8/site-packages (from langchain-core<0.3.0,>=0.2.12->langchain_community) (24.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./myvenv/lib/python3.8/site-packages (from requests<3,>=2->langchain_community) (2.2.2)
# Requirement already satisfied: idna<4,>=2.5 in ./myvenv/lib/python3.8/site-packages (from requests<3,>=2->langchain_community) (3.7)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./myvenv/lib/python3.8/site-packages (from requests<3,>=2->langchain_community) (3.3.2)
# Requirement already satisfied: certifi>=2017.4.17 in ./myvenv/lib/python3.8/site-packages (from requests<3,>=2->langchain_community) (2024.7.4)
# Collecting aiosignal>=1.1.2 (from aiohttp<4.0.0,>=3.8.3->langchain_community)
#   Using cached https://files.pythonhosted.org/packages/76/ac/a7305707cb852b7e16ff80eaf5692309bde30e2b1100a1fcacdc8f731d97/aiosignal-1.3.1-py3-none-any.whl
# Collecting multidict<7.0,>=4.5 (from aiohttp<4.0.0,>=3.8.3->langchain_community)
#   Using cached https://files.pythonhosted.org/packages/6c/13/97f4a2e0e26b7c6e2469de03f1efc255ce2f984a537c301d957762a23eba/multidict-6.0.5-cp38-cp38-macosx_10_9_x86_64.whl
# Collecting frozenlist>=1.1.1 (from aiohttp<4.0.0,>=3.8.3->langchain_community)
#   Using cached https://files.pythonhosted.org/packages/07/eb/71b5531dfb71eb6272b6e2281139d7d46b6adaf43c59850bc8ff64ac1860/frozenlist-1.4.1-cp38-cp38-macosx_10_9_x86_64.whl
# Collecting attrs>=17.3.0 (from aiohttp<4.0.0,>=3.8.3->langchain_community)
#   Using cached https://files.pythonhosted.org/packages/e0/44/827b2a91a5816512fcaf3cc4ebc465ccd5d598c45cefa6703fcf4a79018f/attrs-23.2.0-py3-none-any.whl
# Collecting yarl<2.0,>=1.0 (from aiohttp<4.0.0,>=3.8.3->langchain_community)
#   Using cached https://files.pythonhosted.org/packages/46/ea/8404aa172ffe74da750efeb09aa293bf0247fa6ab4f593aea93f85f74844/yarl-1.9.4-cp38-cp38-macosx_10_9_x86_64.whl
# Requirement already satisfied: pydantic-core==2.20.1 in ./myvenv/lib/python3.8/site-packages (from pydantic<3,>=1; python_full_version < "3.12.4"->langsmith<0.2.0,>=0.1.0->langchain_community) (2.20.1)
# Requirement already satisfied: annotated-types>=0.4.0 in ./myvenv/lib/python3.8/site-packages (from pydantic<3,>=1; python_full_version < "3.12.4"->langsmith<0.2.0,>=0.1.0->langchain_community) (0.7.0)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain_community)
#   Downloading https://files.pythonhosted.org/packages/2a/e2/5d3f6ada4297caebe1a2add3b126fe800c96f56dbe5d1988a2cbe0b267aa/mypy_extensions-1.0.0-py3-none-any.whl
# Requirement already satisfied: jsonpointer>=1.9 in ./myvenv/lib/python3.8/site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.3.0,>=0.2.12->langchain_community) (3.0.0)
# Building wheels for collected packages: greenlet
#   Building wheel for greenlet (PEP 517) ... error
#   ERROR: Command errored out with exit status 1:
#    command: /Users/saranath/PythonQuestionMaker/myvenv/bin/python3 /Users/saranath/PythonQuestionMaker/myvenv/lib/python3.8/site-packages/pip/_vendor/pep517/_in_process.py build_wheel /var/folders/1n/pwgq7wc56_9b_0rsfsb8v_180000gn/T/tmp4gmbgsiv
#        cwd: /private/var/folders/1n/pwgq7wc56_9b_0rsfsb8v_180000gn/T/pip-install-xoev7fk_/greenlet
#   Complete output (213 lines):
#   running bdist_wheel
#   running build
#   running build_py
#   creating build
#   creating build/lib.macosx-10.14.6-x86_64-cpython-38
#   creating build/lib.macosx-10.14.6-x86_64-cpython-38/greenlet
#   copying src/greenlet/__init__.py -> build/lib.macosx-10.14.6-x86_64-cpython-38/greenlet
#   creating build/lib.macosx-10.14.6-x86_64-cpython-38/greenlet/platform
#   copying src/greenlet/platform/__init__.py -> build/lib.macosx-10.14.6-x86_64-cpython-38/greenlet/platform
#   creating build/lib.macosx-10.14.6-x86_64-cpython-38/greenlet/tests
#   copying src/greenlet/tests/test_version.py -> build/lib.macosx-10.14.6-x86_64-cpython-38/greenlet/tests
#   copying src/greenlet/tests/test_weakref.py -> build/lib.macosx-10.14.6-x86_64-cpython-38/greenlet/tests
#   copying src/greenlet/tests/fail_slp_switch.py -> build/lib.macosx-10.14.6-x86_64-cpython-38/greenlet/tests
#   copying src/greenlet/tests/test_gc.py -> build/lib.macosx-10.14.6-x86_64-cpython-38/greenlet/tests
#   copying src/greenlet/tests/leakcheck.py -> build/lib.macosx-10.14.6-x86_64-cpython-38/greenlet/tests
#   copying src/greenlet/tests/fail_switch_two_greenlets.py -> build/lib.macosx-10.14.6-x86_64-cpython-38/greenlet/tests
#   copying src/greenlet/tests/test_generator.py -> build/lib.macosx-10.14.6-x86_64-cpython-38/greenlet/tests
#   copying src/greenlet/tests/test_greenlet_trash.py -> build/lib.macosx-10.14.6-x86_64-cpython-38/greenlet/tests
#   copying src/greenlet/tests/test_throw.py -> build/lib.macosx-10.14.6-x86_64-cpython-38/greenlet/tests
#   copying src/greenlet/tests/test_tracing.py -> build/lib.macosx-10.14.6-x86_64-cpython-38/greenlet/tests
#   copying src/greenlet/tests/fail_cpp_exception.py -> build/lib.macosx-10.14.6-x86_64-cpython-38/greenlet/tests
#   copying src/greenlet/tests/fail_switch_three_greenlets.py -> build/lib.macosx-10.14.6-x86_64-cpython-38/greenlet/tests
#   copying src/greenlet/tests/test_cpp.py -> build/lib.macosx-10.14.6-x86_64-cpython-38/greenlet/tests
#   copying src/greenlet/tests/test_contextvars.py -> build/lib.macosx-10.14.6-x86_64-cpython-38/greenlet/tests
#   copying src/greenlet/tests/test_greenlet.py -> build/lib.macosx-10.14.6-x86_64-cpython-38/greenlet/tests
#   copying src/greenlet/tests/test_extension_interface.py -> build/lib.macosx-10.14.6-x86_64-cpython-38/greenlet/tests
#   copying src/greenlet/tests/fail_clearing_run_switches.py -> build/lib.macosx-10.14.6-x86_64-cpython-38/greenlet/tests
#   copying src/greenlet/tests/__init__.py -> build/lib.macosx-10.14.6-x86_64-cpython-38/greenlet/tests
#   copying src/greenlet/tests/fail_switch_three_greenlets2.py -> build/lib.macosx-10.14.6-x86_64-cpython-38/greenlet/tests
#   copying src/greenlet/tests/fail_initialstub_already_started.py -> build/lib.macosx-10.14.6-x86_64-cpython-38/greenlet/tests
#   copying src/greenlet/tests/test_generator_nested.py -> build/lib.macosx-10.14.6-x86_64-cpython-38/greenlet/tests
#   copying src/greenlet/tests/test_stack_saved.py -> build/lib.macosx-10.14.6-x86_64-cpython-38/greenlet/tests
#   copying src/greenlet/tests/test_leaks.py -> build/lib.macosx-10.14.6-x86_64-cpython-38/greenlet/tests
#   running egg_info
#   writing src/greenlet.egg-info/PKG-INFO
#   writing dependency_links to src/greenlet.egg-info/dependency_links.txt
#   writing requirements to src/greenlet.egg-info/requires.txt
#   writing top-level names to src/greenlet.egg-info/top_level.txt
#   reading manifest file 'src/greenlet.egg-info/SOURCES.txt'
#   reading manifest template 'MANIFEST.in'
#   warning: no previously-included files found matching 'benchmarks/*.json'
#   no previously-included directories found matching 'docs/_build'
#   warning: no files found matching '*.py' under directory 'appveyor'
#   warning: no previously-included files matching '*.pyc' found anywhere in distribution
#   warning: no previously-included files matching '*.pyd' found anywhere in distribution
#   warning: no previously-included files matching '*.so' found anywhere in distribution
#   warning: no previously-included files matching '.coverage' found anywhere in distribution
#   adding license file 'LICENSE'
#   adding license file 'LICENSE.PSF'
#   adding license file 'AUTHORS'
#   writing manifest file 'src/greenlet.egg-info/SOURCES.txt'
#   copying src/greenlet/TBrokenGreenlet.cpp -> build/lib.macosx-10.14.6-x86_64-cpython-38/greenlet
#   copying src/greenlet/TExceptionState.cpp -> build/lib.macosx-10.14.6-x86_64-cpython-38/greenlet
#   copying src/greenlet/TGreenlet.cpp -> build/lib.macosx-10.14.6-x86_64-cpython-38/greenlet
#   copying src/greenlet/TGreenletGlobals.cpp -> build/lib.macosx-10.14.6-x86_64-cpython-38/greenlet
#   copying src/greenlet/TMainGreenlet.cpp -> build/lib.macosx-10.14.6-x86_64-cpython-38/greenlet
#   copying src/greenlet/TPythonState.cpp -> build/lib.macosx-10.14.6-x86_64-cpython-38/greenlet
#   copying src/greenlet/TStackState.cpp -> build/lib.macosx-10.14.6-x86_64-cpython-38/greenlet
#   copying src/greenlet/TThreadStateDestroy.cpp -> build/lib.macosx-10.14.6-x86_64-cpython-38/greenlet
#   copying src/greenlet/TUserGreenlet.cpp -> build/lib.macosx-10.14.6-x86_64-cpython-38/greenlet
#   copying src/greenlet/greenlet.cpp -> build/lib.macosx-10.14.6-x86_64-cpython-38/greenlet
#   copying src/greenlet/greenlet.h -> build/lib.macosx-10.14.6-x86_64-cpython-38/greenlet
#   copying src/greenlet/greenlet_allocator.hpp -> build/lib.macosx-10.14.6-x86_64-cpython-38/greenlet
#   copying src/greenlet/greenlet_compiler_compat.hpp -> build/lib.macosx-10.14.6-x86_64-cpython-38/greenlet
#   copying src/greenlet/greenlet_cpython_add_pending.hpp -> build/lib.macosx-10.14.6-x86_64-cpython-38/greenlet
#   copying src/greenlet/greenlet_cpython_compat.hpp -> build/lib.macosx-10.14.6-x86_64-cpython-38/greenlet
#   copying src/greenlet/greenlet_exceptions.hpp -> build/lib.macosx-10.14.6-x86_64-cpython-38/greenlet
#   copying src/greenlet/greenlet_greenlet.hpp -> build/lib.macosx-10.14.6-x86_64-cpython-38/greenlet
#   copying src/greenlet/greenlet_internal.hpp -> build/lib.macosx-10.14.6-x86_64-cpython-38/greenlet
#   copying src/greenlet/greenlet_refs.hpp -> build/lib.macosx-10.14.6-x86_64-cpython-38/greenlet
#   copying src/greenlet/greenlet_slp_switch.hpp -> build/lib.macosx-10.14.6-x86_64-cpython-38/greenlet
#   copying src/greenlet/greenlet_thread_state.hpp -> build/lib.macosx-10.14.6-x86_64-cpython-38/greenlet
#   copying src/greenlet/greenlet_thread_state_dict_cleanup.hpp -> build/lib.macosx-10.14.6-x86_64-cpython-38/greenlet
#   copying src/greenlet/greenlet_thread_support.hpp -> build/lib.macosx-10.14.6-x86_64-cpython-38/greenlet
#   copying src/greenlet/slp_platformselect.h -> build/lib.macosx-10.14.6-x86_64-cpython-38/greenlet
#   copying src/greenlet/platform/setup_switch_x64_masm.cmd -> build/lib.macosx-10.14.6-x86_64-cpython-38/greenlet/platform
#   copying src/greenlet/platform/switch_aarch64_gcc.h -> build/lib.macosx-10.14.6-x86_64-cpython-38/greenlet/platform
#   copying src/greenlet/platform/switch_alpha_unix.h -> build/lib.macosx-10.14.6-x86_64-cpython-38/greenlet/platform
#   copying src/greenlet/platform/switch_amd64_unix.h -> build/lib.macosx-10.14.6-x86_64-cpython-38/greenlet/platform
#   copying src/greenlet/platform/switch_arm32_gcc.h -> build/lib.macosx-10.14.6-x86_64-cpython-38/greenlet/platform
#   copying src/greenlet/platform/switch_arm32_ios.h -> build/lib.macosx-10.14.6-x86_64-cpython-38/greenlet/platform
#   copying src/greenlet/platform/switch_arm64_masm.asm -> build/lib.macosx-10.14.6-x86_64-cpython-38/greenlet/platform
#   copying src/greenlet/platform/switch_arm64_masm.obj -> build/lib.macosx-10.14.6-x86_64-cpython-38/greenlet/platform
#   copying src/greenlet/platform/switch_arm64_msvc.h -> build/lib.macosx-10.14.6-x86_64-cpython-38/greenlet/platform
#   copying src/greenlet/platform/switch_csky_gcc.h -> build/lib.macosx-10.14.6-x86_64-cpython-38/greenlet/platform
#   copying src/greenlet/platform/switch_loongarch64_linux.h -> build/lib.macosx-10.14.6-x86_64-cpython-38/greenlet/platform
#   copying src/greenlet/platform/switch_m68k_gcc.h -> build/lib.macosx-10.14.6-x86_64-cpython-38/greenlet/platform
#   copying src/greenlet/platform/switch_mips_unix.h -> build/lib.macosx-10.14.6-x86_64-cpython-38/greenlet/platform
#   copying src/greenlet/platform/switch_ppc64_aix.h -> build/lib.macosx-10.14.6-x86_64-cpython-38/greenlet/platform
#   copying src/greenlet/platform/switch_ppc64_linux.h -> build/lib.macosx-10.14.6-x86_64-cpython-38/greenlet/platform
#   copying src/greenlet/platform/switch_ppc_aix.h -> build/lib.macosx-10.14.6-x86_64-cpython-38/greenlet/platform
#   copying src/greenlet/platform/switch_ppc_linux.h -> build/lib.macosx-10.14.6-x86_64-cpython-38/greenlet/platform
#   copying src/greenlet/platform/switch_ppc_macosx.h -> build/lib.macosx-10.14.6-x86_64-cpython-38/greenlet/platform
#   copying src/greenlet/platform/switch_ppc_unix.h -> build/lib.macosx-10.14.6-x86_64-cpython-38/greenlet/platform
#   copying src/greenlet/platform/switch_riscv_unix.h -> build/lib.macosx-10.14.6-x86_64-cpython-38/greenlet/platform
#   copying src/greenlet/platform/switch_s390_unix.h -> build/lib.macosx-10.14.6-x86_64-cpython-38/greenlet/platform
#   copying src/greenlet/platform/switch_sparc_sun_gcc.h -> build/lib.macosx-10.14.6-x86_64-cpython-38/greenlet/platform
#   copying src/greenlet/platform/switch_x32_unix.h -> build/lib.macosx-10.14.6-x86_64-cpython-38/greenlet/platform
#   copying src/greenlet/platform/switch_x64_masm.asm -> build/lib.macosx-10.14.6-x86_64-cpython-38/greenlet/platform
#   copying src/greenlet/platform/switch_x64_masm.obj -> build/lib.macosx-10.14.6-x86_64-cpython-38/greenlet/platform
#   copying src/greenlet/platform/switch_x64_msvc.h -> build/lib.macosx-10.14.6-x86_64-cpython-38/greenlet/platform
#   copying src/greenlet/platform/switch_x86_msvc.h -> build/lib.macosx-10.14.6-x86_64-cpython-38/greenlet/platform
#   copying src/greenlet/platform/switch_x86_unix.h -> build/lib.macosx-10.14.6-x86_64-cpython-38/greenlet/platform
#   copying src/greenlet/tests/_test_extension.c -> build/lib.macosx-10.14.6-x86_64-cpython-38/greenlet/tests
#   copying src/greenlet/tests/_test_extension_cpp.cpp -> build/lib.macosx-10.14.6-x86_64-cpython-38/greenlet/tests
#   running build_ext
#   building 'greenlet._greenlet' extension
#   creating build/temp.macosx-10.14.6-x86_64-cpython-38
#   creating build/temp.macosx-10.14.6-x86_64-cpython-38/src
#   creating build/temp.macosx-10.14.6-x86_64-cpython-38/src/greenlet
#   clang -Wno-unused-result -Wsign-compare -Wunreachable-code -fno-common -dynamic -DNDEBUG -g -fwrapv -O3 -Wall -iwithsysroot/System/Library/Frameworks/System.framework/PrivateHeaders -iwithsysroot/Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.8/Headers -arch arm64 -arch x86_64 -I/Users/saranath/PythonQuestionMaker/myvenv/include -I/Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.8/include/python3.8 -c src/greenlet/greenlet.cpp -o build/temp.macosx-10.14.6-x86_64-cpython-38/src/greenlet/greenlet.o --std=gnu++11
#   In file included from src/greenlet/greenlet.cpp:9:
#   In file included from /Library/Developer/CommandLineTools/usr/bin/../include/c++/v1/cstdlib:85:
#   In file included from /Library/Developer/CommandLineTools/usr/bin/../include/c++/v1/stdlib.h:97:
#   In file included from /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdlib.h:62:
#   /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/sys/cdefs.h:807:2: error: Unsupported architecture
#   #error Unsupported architecture
#    ^
#   In file included from src/greenlet/greenlet.cpp:9:
#   In file included from /Library/Developer/CommandLineTools/usr/bin/../include/c++/v1/cstdlib:85:
#   In file included from /Library/Developer/CommandLineTools/usr/bin/../include/c++/v1/stdlib.h:97:
#   In file included from /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdlib.h:64:
#   In file included from /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/_types.h:27:
#   In file included from /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/sys/_types.h:33:
#   /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/machine/_types.h:34:2: error: architecture not supported
#   #error architecture not supported
#    ^
#   In file included from src/greenlet/greenlet.cpp:9:
#   In file included from /Library/Developer/CommandLineTools/usr/bin/../include/c++/v1/cstdlib:85:
#   In file included from /Library/Developer/CommandLineTools/usr/bin/../include/c++/v1/stdlib.h:97:
#   In file included from /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdlib.h:64:
#   In file included from /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/_types.h:27:
#   /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/sys/_types.h:55:9: error: unknown type name '__int64_t'
#   typedef __int64_t       __darwin_blkcnt_t;      /* total blocks */
#           ^
#   /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/sys/_types.h:56:9: error: unknown type name '__int32_t'; did you mean '__int128_t'?
#   typedef __int32_t       __darwin_blksize_t;     /* preferred block size */
#           ^
#   note: '__int128_t' declared here
#   /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/sys/_types.h:57:9: error: unknown type name '__int32_t'; did you mean '__int128_t'?
#   typedef __int32_t       __darwin_dev_t;         /* dev_t */
#           ^
#   note: '__int128_t' declared here
#   /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/sys/_types.h:60:9: error: unknown type name '__uint32_t'; did you mean '__uint128_t'?
#   typedef __uint32_t      __darwin_gid_t;         /* [???] process and group IDs */
#           ^
#   note: '__uint128_t' declared here
#   /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/sys/_types.h:61:9: error: unknown type name '__uint32_t'; did you mean '__uint128_t'?
#   typedef __uint32_t      __darwin_id_t;          /* [XSI] pid_t, uid_t, or gid_t*/
#           ^
#   note: '__uint128_t' declared here
#   /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/sys/_types.h:62:9: error: unknown type name '__uint64_t'
#   typedef __uint64_t      __darwin_ino64_t;       /* [???] Used for 64 bit inodes */
#           ^
#   /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/sys/_types.h:68:9: error: unknown type name '__darwin_natural_t'
#   typedef __darwin_natural_t __darwin_mach_port_name_t; /* Used by mach */
#           ^
#   /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/sys/_types.h:70:9: error: unknown type name '__uint16_t'; did you mean '__uint128_t'?
#   typedef __uint16_t      __darwin_mode_t;        /* [???] Some file attributes */
#           ^
#   note: '__uint128_t' declared here
#   /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/sys/_types.h:71:9: error: unknown type name '__int64_t'
#   typedef __int64_t       __darwin_off_t;         /* [???] Used for file sizes */
#           ^
#   /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/sys/_types.h:72:9: error: unknown type name '__int32_t'; did you mean '__int128_t'?
#   typedef __int32_t       __darwin_pid_t;         /* [???] process and group IDs */
#           ^
#   note: '__int128_t' declared here
#   /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/sys/_types.h:73:9: error: unknown type name '__uint32_t'; did you mean '__uint128_t'?
#   typedef __uint32_t      __darwin_sigset_t;      /* [???] signal set */
#           ^
#   note: '__uint128_t' declared here
#   /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/sys/_types.h:74:9: error: unknown type name '__int32_t'; did you mean '__int128_t'?
#   typedef __int32_t       __darwin_suseconds_t;   /* [???] microseconds */
#           ^
#   note: '__int128_t' declared here
#   /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/sys/_types.h:75:9: error: unknown type name '__uint32_t'; did you mean '__uint128_t'?
#   typedef __uint32_t      __darwin_uid_t;         /* [???] user IDs */
#           ^
#   note: '__uint128_t' declared here
#   /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/sys/_types.h:76:9: error: unknown type name '__uint32_t'; did you mean '__uint128_t'?
#   typedef __uint32_t      __darwin_useconds_t;    /* [???] microseconds */
#           ^
#   note: '__uint128_t' declared here
#   In file included from src/greenlet/greenlet.cpp:9:
#   In file included from /Library/Developer/CommandLineTools/usr/bin/../include/c++/v1/cstdlib:85:
#   In file included from /Library/Developer/CommandLineTools/usr/bin/../include/c++/v1/stdlib.h:97:
#   In file included from /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdlib.h:64:
#   /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/_types.h:43:9: error: unknown type name '__uint32_t'; did you mean '__uint128_t'?
#   typedef __uint32_t      __darwin_wctype_t;
#           ^
#   note: '__uint128_t' declared here
#   In file included from src/greenlet/greenlet.cpp:9:
#   In file included from /Library/Developer/CommandLineTools/usr/bin/../include/c++/v1/cstdlib:85:
#   In file included from /Library/Developer/CommandLineTools/usr/bin/../include/c++/v1/stdlib.h:97:
#   In file included from /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdlib.h:66:
#   In file included from /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/sys/wait.h:109:
#   In file included from /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/sys/signal.h:82:
#   /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/machine/signal.h:34:2: error: architecture not supported
#   #error architecture not supported
#    ^
#   In file included from src/greenlet/greenlet.cpp:9:
#   In file included from /Library/Developer/CommandLineTools/usr/bin/../include/c++/v1/cstdlib:85:
#   In file included from /Library/Developer/CommandLineTools/usr/bin/../include/c++/v1/stdlib.h:97:
#   In file included from /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdlib.h:66:
#   In file included from /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/sys/wait.h:109:
#   In file included from /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/sys/signal.h:146:
#   /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/machine/_mcontext.h:31:2: error: architecture not supported
#   #error architecture not supported
#    ^
#   fatal error: too many errors emitted, stopping now [-ferror-limit=]
#   20 errors generated.
#   error: command '/usr/bin/clang' failed with exit code 1
#   ----------------------------------------
#   ERROR: Failed building wheel for greenlet
#   Running setup.py clean for greenlet
# Failed to build greenlet
# ERROR: Could not build wheels for greenlet which use PEP 517 and cannot be installed directly
# WARNING: You are using pip version 19.2.3, however version 24.1.2 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %% [markdown]
# # Load JSON

# %%
import json

with open('apiKeys.json', 'r') as file:

    apiKeys = json.load(file)

# %%
import os

os.environ["LANGCHAIN_TRACING_V2"] = "true"
os.environ["LANGCHAIN_API_KEY"] = apiKeys['LANGCHAIN_API_KEY']

# %% [markdown]
# # Loading LLAMA 8B Model

# %%
import os

os.environ["GROQ_API_KEY"] = apiKeys['GROQ_API_KEY']

from langchain_groq import ChatGroq

model = ChatGroq(model="llama3-8b-8192")

# %% [markdown]
# ## Example Usage

# %%
prompt = f"Hi, What's up!"

response = model.invoke([prompt])
response.content
# Out:
# "Hi! Not much, just an AI waiting to chat with you! How about you? How's your day going so far?"

# %% [markdown]
# # Workflow of the project
#
# ![diagram-20240715.svg](data:image/svg+xml;base64,...)

# %% [markdown]
# # Performing the last part of the workflow

# %% [markdown]
# ## Problem 1
#
# ```
# Input  : Concept, Theme
# Output : JSON Parsable
# ```

# %%
from langchain.chains import SimpleSequentialChain
from langchain.prompts import ChatPromptTemplate
from langchain.chains import LLMChain
from langchain_core.messages import HumanMessage, SystemMessage,AIMessage

# %%
concept = "strings"
theme = "animie"

# %% [markdown]
# # One Shot Learning

# %%
problem_statement = "Write a python program to add the total scores of the batsman in his two innings"
function_name = "add"
function_template = "def add_scores(score1, score2):\n    # Your code here\n    pass"
test_cases = [
    {
        "input": "10, 20",
        "output": "30"
    },
    {
        "input": "46, 52",
        "output": "98"
    }
]

example_output = f"""
{{
    "problem_statement": "{problem_statement}",
    "function_name": "{function_name}",
    "function_template": "{function_template}",
    "test_cases": [
        {{
            "input": "{test_cases[0]['input']}",
            "output": "{test_cases[0]['output']}"
        }},
        {{
            "input": "{test_cases[1]['input']}",
            "output": "{test_cases[1]['output']}"
        }}
    ]
}}
"""

# %%
messages = [
    SystemMessage(content="Generate a valid python programming question with 2 or more test cases for the given concept and theme in json format strictly."),
    HumanMessage(content=f"Concept : functions, Theme : cricket"),
    AIMessage(content=example_output),
    HumanMessage(content=f"Concept : {concept}, Theme : {theme}")
]

# %%
print(model.invoke(messages).content)
# Out:
# {
#     "problem_statement": "Write a python program to extract the name of the main character from a given anime title",
#     "function_name": "extract_name",
#     "function_template": "def extract_name(anime_title):
#     # Your code here
#     pass",
#     "test_cases": [
#         {
#             "input": "Attack on Titan",
#             "output": "No main character name provided"
#         },
#         {
#             "input": "Naruto Uzumaki",
#             "output": "Naruto Uzumaki"
#         },
#         {
#             "input": "Dragon Ball Z",
#             "output": "Goku"
#         }
#     ]
# }

# %% [markdown]
# # A module which makes us questions

# %%
import random
import json

class QuestionMaker:

    def __init__(self, userConcepts, userInterests, model_name="llama3-8b-8192"):

        self.userConcepts = userConcepts
        self.userInterests = userInterests
        self.model = ChatGroq(model=model_name)


    def frame_a_question(self, userConcept, userInterest):
        problem_statement_1 = "Write a python program to add the total scores of the batsman in his two innings"
        function_name_1 = "add"
        function_template_1 = "def add_scores(score1, score2):\\n    # Your code here\\n    pass"
        test_cases_1 = [
            {
                "input": "10, 20",
                "output": "30"
            },
            {
                "input": "46, 52",
                "output": "98"
            }
        ]
        
        example_output_1 = f"""
        {{
            "userConcept" : "functions",
            "userInterest" : "cricket"
            "problem_statement": "{problem_statement_1}",
            "function_name": "{function_name_1}",
            "function_template": "{function_template_1}",
            "test_cases": [
                {{
                    "input": "{test_cases_1[0]['input']}",
                    "output": "{test_cases_1[0]['output']}"
                }},
                {{
                    "input": "{test_cases_1[1]['input']}",
                    "output": "{test_cases_1[1]['output']}"
                }}
            ]
        }}
        """
        
        problem_statement_2 = "Write a Python program to read a file named 'fruits.txt' and list out all the fruits in a python list."
        function_name_2 = "display_fruits"
        function_template_2 = "def display_fruits(filename):\\n    # Your code here\\n    pass"
        test_cases_2 = [
            {
                "input": "fruits.txt",
                "content" : "apple \\n mango \\n banana",
                "output": "['apple', 'mango', 'banana']"
            },
            {
                "input": "fruits.txt",
                "content" : "blueberry \\n strawberry \\n raspberry",
                "output": "['blueberry', 'strawberry', 'raspberry']"
            }
        ]
        
        example_output_2 = f"""
        {{
            "userConcept" : "file handling",
            "userInterest" : "fruits"
            "problem_statement": "{problem_statement_2}",
            "function_name": "{function_name_2}",
            "function_template": "{function_template_2}",
            "test_cases": [
                {{
                    "input": "{test_cases_2[0]['input']}",
                    "content" : "{test_cases_2[0]['content']}",
                    "output": "{test_cases_2[0]['output']}"
                }},
                {{
                    "input": "{test_cases_2[1]['input']}",
                    "content" : "{test_cases_2[1]['content']}",
                    "output": "{test_cases_2[1]['output']}"
                }}
            ]
        }}
        """
        
        
        messages = [
            SystemMessage(content=f"""
            Generate a valid python programming question with 2 or more test cases for the given 
            concept and theme in json format strictly without any other extra sentances.
            """),
            HumanMessage(content=f"Concept : functions, Theme : cricket"),
            AIMessage(content=example_output_1),
            HumanMessage(content=f"Concept : file handling, Theme : fruits"),
            AIMessage(content=example_output_2),
            HumanMessage(content=f"Concept : {userConcept}, Theme : {userInterest}")
        ]

        return model.invoke(messages).content

    def get_questions(self, n):

        questions = set()

        while len(questions) < n:
            userConcept = random.choice(self.userConcepts)
            userInterest = random.choice(self.userInterests)
            question = self.frame_a_question(userConcept, userInterest)
            questions.add(question)

        return list(questions)

# %% [markdown]
# # Having 1 user and many topics and interests.

# %%
user_json = [
    {
        "username" : "example",
        "rollNumber" : "21F1000001",
        "userConcepts" : ["functions", "file handling", "list comprehension"],
        "userInterests" : ["cricket", "tamil movies", "tamil music", "cars", "animie"]
    }
]

# %%
questionMaker = QuestionMaker(user_json[0]["userConcepts"], user_json[0]["userInterests"])

userQuestions = questionMaker.get_questions(10)

print(userQuestions)
# Out:
# ['{\n    "userConcept" : "list comprehension",\n    "userInterest" : "cricket"\n    "problem_statement": "Write a Python program to create a list of cricket players\' names using a list comprehension from a given list of tuples, where each tuple contains the player\'s name and his average score.",\n    "function_name": "create_player_names",\n    "function_template": "def create_player_names(player_data):\\n    # Your code here\\n    pass",\n    "test_cases": [\n        {\n            "input": "[(\'Rahul\', 30), (\'Dhoni\', 45), (\'Kohli\', 50), (\'Rohit\', 40)]",\n            "output": ["Rahul", "Dhoni", "Kohli", "Rohit"]\n        },\n        {\n            "input": "[(\'Sharma\', 35), (\'Pandya\', 40), (\'Bumrah\', 30), (\'Jadeja\', 45)]",\n            "output": ["Sharma", "Pandya", "Bumrah", "Jadeja"]\n        }\n    ]\n}\n', '{\n    "userConcept" : "functions",\n    "userInterest" : "cars"\n    "problem_statement": "Write a Python program that defines a function to calculate the fuel efficiency of a car in miles per gallon (mpg) given the distance traveled and the amount of fuel consumed.",\n    "function_name": "calculate_mpg",\n    "function_template": "def calculate_mpg(distance, fuel):\\n    # Your code here\\n    pass",\n    "test_cases": [\n        {\n            "input": "100, 5",\n            "output": "20.0"\n        },\n        {\n            "input": "200, 10",\n            "output": "20.0"\n        }\n    ]\n}', '{\n    "userConcept" : "functions",\n    "userInterest" : "tamil music"\n    "problem_statement": "Write a Python program to create a function that takes a song title and returns the singer of the song from a predefined dictionary.",\n    "function_name": "get_singer",\n    "function_template": "def get_singer(song_title):\\n    # Your code here\\n    pass",\n    "test_cases": [\n        {\n            "input": "Kadhalum Kadandhu Pogum",\n            "output": "A.R.Rahman"\n        },\n        {\n            "input": "Chennai 28",\n            "output": "Yuvan Shankar Raja"\n        }\n    ]\n}', '{\n    "userConcept" : "functions",\n    "userInterest" : "cricket"\n    "problem_statement": "Write a Python program to calculate the total runs scored by a team in a cricket match, given the runs scored by each batsman",\n    "function_name": "total_runs",\n    "function_template": "def total_runs(scores):\\n    # Your code here\\n    pass",\n    "test_cases": [\n        {\n            "input": "[50, 30, 20]",\n            "output": "100"\n        },\n        {\n            "input": "[100, 80, 60]",\n            "output": "240"\n        }\n    ]\n}', '{\n    "userConcept" : "list comprehension",\n    "userInterest" : "tamil music"\n    "problem_statement": "Write a Python program to create a list of popular Tamil music directors using list comprehension",\n    "function_name": "get_directors",\n    "function_template": "def get_directors(directors):\\n    # Your code here\\n    pass",\n    "test_cases": [\n        {\n            "input": ["Imman, Harris, A.R. Rahman"],\n            "output": ["Imman", "Harris", "A.R. Rahman"]\n        },\n        {\n            "input": ["Vishal-Shekhar, G.V. Prakash, Yuvan"],\n            "output": ["Vishal-Shekhar", "G.V. Prakash", "Yuvan"]\n        }\n    ]\n}', '{\n    "userConcept" : "list comprehension",\n    "userInterest" : "tamil music"\n    "problem_statement": "Write a Python program to create a list of all the songs from the album \'Pudhiya Mugam\' by Ilaiyaraaja, given the list of songs as a string",\n    "function_name": "get_songs",\n    "function_template": "def get_songs(album_songs):\\n    # Your code here\\n    pass",\n    "test_cases": [\n        {\n            "input": "\'Aadatha Aattam Ellaam, Kanne Kannil, Manjam Porumai, Ennai Theril, Pudhiya Thendral\'",\n            "output": ["Aadatha Aattam Ellaam", "Kanne Kannil", "Manjam Porumai", "Ennai Theril", "Pudhiya Thendral"]\n        },\n        {\n            "input": "\'Ettu Thatha, Adi Ennadi, Kurunt ...

# %%
for i in range(len(userQuestions)):
    print(userQuestions[i])
# Out:
# {
#     "userConcept" : "list comprehension",
#     "userInterest" : "cricket"
#     "problem_statement": "Write a Python program to create a list of cricket players' names using a list comprehension from a given list of tuples, where each tuple contains the player's name and his average score.",
#     "function_name": "create_player_names",
#     "function_template": "def create_player_names(player_data):\n    # Your code here\n    pass",
#     "test_cases": [
#         {
#             "input": "[('Rahul', 30), ('Dhoni', 45), ('Kohli', 50), ('Rohit', 40)]",
#             "output": ["Rahul", "Dhoni", "Kohli", "Rohit"]
#         },
#         {
#             "input": "[('Sharma', 35), ('Pandya', 40), ('Bumrah', 30), ('Jadeja', 45)]",
#             "output": ["Sharma", "Pandya", "Bumrah", "Jadeja"]
#         }
#     ]
# }
#
# {
#     "userConcept" : "functions",
#     "userInterest" : "cars"
#     "problem_statement": "Write a Python program that defines a function to calculate the fuel efficiency of a car in miles per gallon (mpg) given the distance traveled and the amount of fuel consumed.",
#     "function_name": "calculate_mpg",
#     "function_template": "def calculate_mpg(distance, fuel):\n    # Your code here\n    pass",
#     "test_cases": [
#         {
#             "input": "100, 5",
#             "output": "20.0"
#         },
#         {
#             "input": "200, 10",
#             "output": "20.0"
#         }
#     ]
# }
# {
#     "userConcept" : "functions",
#     "userInterest" : "tamil music"
#     "problem_statement": "Write a Python program to create a function that takes a song title and returns the singer of the song from a predefined dictionary.",
#     "function_name": "get_singer",
#     "function_template": "def get_singer(song_title):\n    # Your code here\n    pass",
#     "test_cases": [
#         {
#             "input": "Kadhalum Kadandhu Pogum",
#             "output": "A.R.Rahman"
#         },
#         {
#             "input": "Chennai 28",
#             "output": "Yuvan Shankar Raja"
#         }
#     ]
# }
# {
#     "userConcept" : "functions",
#     "userInterest" : "cricket"
#     "problem_statement": "Write a Python program to calculate the total runs scored by a team in a cricket match, given the runs scored by each batsman",
#     "function_name": "total_runs",
#     "function_template": "def total_runs(scores):\n    # Your code here\n    pass",
#     "test_cases": [
#         {
#             "input": "[50, 30, 20]",
#             "output": "100"
#         },
#         {
#             "input": "[100, 80, 60]",
#             "output": "240"
#         }
#     ]
# }
# {
#     "userConcept" : "list comprehension",
#     "userInterest" : "tamil music"
#     "problem_statement": "Write a Python program to create a list of popular Tamil music directors using list comprehension",
#     "function_name": "get_directors",
#     "function_template": "def get_directors(directors):\n    # Your code here\n    pass",
#     "test_cases": [
#         {
#             "input": ["Imman, Harris, A.R. Rahman"],
#             "output": ["Imman", "Harris", "A.R. Rahman"]
#         },
#         {
#             "input": ["Vishal-Shekhar, G.V. Prakash, Yuvan"],
#             "output": ["Vishal-Shekhar", "G.V. Prakash", "Yuvan"]
#         }
#     ]
# }
# {
#     "userConcept" : "list comprehension",
#     "userInterest" : "tamil music"
#     "problem_statement": "Write a Python program to create a list of all the songs from the album 'Pudhiya Mugam' by Ilaiyaraaja, given the list of songs as a string",
#     "function_name": "get_songs",
#     "function_template": "def get_songs(album_songs):\n    # Your code here\n    pass",
#     "test_cases": [
#         {
#             "input": "'Aadatha Aattam Ellaam, Kanne Kannil, Manjam Porumai, Ennai Theril, Pudhiya Thendral'",
#             "output": ["Aadatha Aattam Ellaam", "Kanne Kannil", "Manjam Porumai", "Ennai Theril", "Pudhiya Thendral"]
#         },
#         {
#             "input": "'Ettu Thatha, Adi Ennadi, Kuruntho Police'",
#             "output": ["Ettu Thatha", "Adi Ennadi", "Kuruntho Police"]
#         }
#     ]
# }
# {
#     "userConcept" : "functions",
#     "userInterest" : "anime"
#     "problem_statement": "Write a Python program to create a function named 'anime_ratings' that takes the name of an anime and its rating as input, and returns the rating as a string with ' is a highly rated anime' appended to it if the rating is greater than 8.",
#     "function_name": "anime_ratings",
#     "function_template": "def anime_ratings(anime_name, rating):\n    # Your code here\n    pass",
#     "test_cases": [
#         {
#             "input": "attack_on_titan", "rating": 9,
#             "output": "'attack_on_titan' is a highly rated anime"
#         },
#         {
#             "input": "dragon_ball_z", "rating": 7,
#             "output": "'dragon_ball_z'"
#         }
#     ]
# }
# {
#     "userConcept" : "file handling",
#     "userInterest" : "cricket"
#     "problem_statement": "Write a Python program to read a file named 'matches.txt' and display the names of all the cricketers who have played more than 50 matches.",
#     "function_name": "display_cricketers",
#     "function_template": "def display_cricketers(filename):\n    # Your code here\n    pass",
#     "test_cases": [
#         {
#             "input": "matches.txt",
#             "content" : "Sachin 100\n Dhoni 80\n Kohli 60\n Rohit 70\n Ponting 90",
#             "output": "['Sachin', 'Dhoni', 'Ponting']"
#         },
#         {
#             "input": "matches.txt",
#             "content" : "Warner 120\n Smith 80\n Root 100\n Kohli 60\n de Villiers 90",
#             "output": "['Warner', 'Root', 'Kohli', 'de Villiers']"
#         }
#     ]
# }
# {
#     "userConcept" : "functions",
#     "userInterest" : "cars"
#     "problem_statement": "Write a Python program to create a function that calculates the total cost of a car purchase, including taxes and fees.",
#     "function_name": "calculate_total_cost",
#     "function_template": "def calculate_total_cost(base_price, taxes, fees):\n    # Your code here\n    pass",
#     "test_cases": [
#         {
#             "input": "50000, 0.08, 1000",
#             "output": "54000"
#         },
#         {
#             "input": "70000, 0.09, 1500",
#             "output": "75500"
#         }
#     ]
# }
# {
#     "userConcept" : "file handling",
#     "userInterest" : "anime"
#     "problem_statement": "Write a Python program to write a list of anime characters to a file named 'anime_characters.txt' and then read the file and display the characters.",
#     "function_name": "write_anime_characters",
#     "function_template": "def write_anime_characters(characters):\n    # Your code here\n    pass",
#     "test_cases": [
#         {
#             "input": ["Naruto", "Sasuke", "Sakura"],
#             "output": "Naruto\nSasuke\nSakura\n"
#         },
#         {
#             "input": ["Light", "L", "Misa"],
#             "output": "Light\nL\nMisa\n"
#         }
#     ]
# }

# %%
len(userQuestions)
# Out:
# 10

# %%
json.loads(userQuestions[3])
# Out:
# {'userConcept': 'functions',
#  'userInterest': 'cars',
#  'problem_statement': 'Write a python program to calculate the total cost of a car including taxes and insurance',
#  'function_name': 'calculate_total_cost',
#  'function_template': 'def calculate_total_cost(price, tax_rate, insurance_rate):\n    # Your code here\n    pass',
#  'test_cases': [{'input': '20000, 0.08, 0.05', 'output': '21400.0'},
#   {'input': '35000, 0.1, 0.03', 'output': '37345.0'}]}
